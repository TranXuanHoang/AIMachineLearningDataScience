# %% [markdown]
# # Practical NLP with spaCy
#
# [spaCy](https://spacy.io/) is an industrial Natural Language Processing (NLP) ecosystem with a lot of great features that can simplify comon or complicated NLU tasks.

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import sklearn as sk
import spacy

# %%
# Load NLP models (both English and Japanese)
enlp = spacy.load('en_core_web_trf')
jnlp = spacy.load('ja_core_news_lg')

# %%
# Left-align all columns of a given `dataFrm` DataFrame
def left_align(dataFrm: pd.DataFrame):
  dataFrm = dataFrm.style.set_properties(**{'text-align': 'left'})
  dataFrm = dataFrm.set_table_styles([dict(selector = 'th', props=[('text-align', 'left')])])
  return dataFrm

# Table header
headers = ["Text", "Lemma", "POS", "Tag", "Dep", "Shape", "Is Alpha", "Is Stop"]

# Check if the English NLP model works
edoc = enlp("This is a sentence.")
e_tokens_info = []

for token in edoc:
    e_tokens_info.append([token.text, token.lemma_, token.pos_,
                          token.tag_, token.dep_, token.shape_, token.is_alpha, token.is_stop])

e_table = pd.DataFrame(columns=headers, data=e_tokens_info)
e_table = left_align(e_table)
e_table
# Out:
# <style type="text/css">
# #T_c0657_ th {
#   text-align: left;
# }
# #T_c0657_row0_col0, #T_c0657_row0_col1, #T_c0657_row0_col2, #T_c0657_row0_col3, #T_c0657_row0_col4, #T_c0657_row0_col5, #T_c0657_row0_col6, #T_c0657_row0_col7, #T_c0657_row1_col0, #T_c0657_row1_col1, #T_c0657_row1_col2, #T_c0657_row1_col3, #T_c0657_row1_col4, #T_c0657_row1_col5, #T_c0657_row1_col6, #T_c0657_row1_col7, #T_c0657_row2_col0, #T_c0657_row2_col1, #T_c0657_row2_col2, #T_c0657_row2_col3, #T_c0657_row2_col4, #T_c0657_row2_col5, #T_c0657_row2_col6, #T_c0657_row2_col7, #T_c0657_row3_col0, #T_c0657_row3_col1, #T_c0657_row3_col2, #T_c0657_row3_col3, #T_c0657_row3_col4, #T_c0657_row3_col5, #T_c0657_row3_col6, #T_c0657_row3_col7, #T_c0657_row4_col0, #T_c0657_row4_col1, #T_c0657_row4_col2, #T_c0657_row4_col3, #T_c0657_row4_col4, #T_c0657_row4_col5, #T_c0657_row4_col6, #T_c0657_row4_col7 {
#   text-align: left;
# }
# </style>
# <table id="T_c0657_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Text</th>
#       <th class="col_heading level0 col1" >Lemma</th>
#       <th class="col_heading level0 col2" >POS</th>
#       <th class="col_heading level0 col3" >Tag</th>
#       <th class="col_heading level0 col4" >Dep</th>
#       <th class="col_heading level0 col5" >Shape</th>
#       <th class="col_heading level0 col6" >Is Alpha</th>
#       <th class="col_heading level0 col7" >Is Stop</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0657_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c0657_row0_col0" class="data row0 col0" >This</td>
#       <td id="T_c0657_row0_col1" class="data row0 col1" >this</td>
#       <td id="T_c0657_row0_col2" class="data row0 col2" >DET</td>
#       <td id="T_c0657_row0_col3" class="data row0 col3" >DT</td>
#       <td id="T_c0657_row0_col4" class="data row0 col4" >nsubj</td>
#       <td id="T_c0657_row0_col5" class="data row0 col5" >Xxxx</td>
#       <td id="T_c0657_row0_col6" class="data row0 col6" >True</td>
#       <td id="T_c0657_row0_col7" class="data row0 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c0657_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c0657_row1_col0" class="data row1 col0" >is</td>
#       <td id="T_c0657_row1_col1" class="data row1 col1" >be</td>
#       <td id="T_c0657_row1_col2" class="data row1 col2" >AUX</td>
#       <td id="T_c0657_row1_col3" class="data row1 col3" >VBZ</td>
#       <td id="T_c0657_row1_col4" class="data row1 col4" >ROOT</td>
#       <td id="T_c0657_row1_col5" class="data row1 col5" >xx</td>
#       <td id="T_c0657_row1_col6" class="data row1 col6" >True</td>
#       <td id="T_c0657_row1_col7" class="data row1 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c0657_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c0657_row2_col0" class="data row2 col0" >a</td>
#       <td id="T_c0657_row2_col1" class="data row2 col1" >a</td>
#       <td id="T_c0657_row2_col2" class="data row2 col2" >DET</td>
#       <td id="T_c0657_row2_col3" class="data row2 col3" >DT</td>
#       <td id="T_c0657_row2_col4" class="data row2 col4" >det</td>
#       <td id="T_c0657_row2_col5" class="data row2 col5" >x</td>
#       <td id="T_c0657_row2_col6" class="data row2 col6" >True</td>
#       <td id="T_c0657_row2_col7" class="data row2 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c0657_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c0657_row3_col0" class="data row3 col0" >sentence</td>
#       <td id="T_c0657_row3_col1" class="data row3 col1" >sentence</td>
#       <td id="T_c0657_row3_col2" class="data row3 col2" >NOUN</td>
#       <td id="T_c0657_row3_col3" class="data row3 col3" >NN</td>
#       <td id="T_c0657_row3_col4" class="data row3 col4" >attr</td>
#       <td id="T_c0657_row3_col5" class="data row3 col5" >xxxx</td>
#       <td id="T_c0657_row3_col6" class="data row3 col6" >True</td>
#       <td id="T_c0657_row3_col7" class="data row3 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c0657_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c0657_row4_col0" class="data row4 col0" >.</td>
#       <td id="T_c0657_row4_col1" class="data row4 col1" >.</td>
#       <td id="T_c0657_row4_col2" class="data row4 col2" >PUNCT</td>
#       <td id="T_c0657_row4_col3" class="data row4 col3" >.</td>
#       <td id="T_c0657_row4_col4" class="data row4 col4" >punct</td>
#       <td id="T_c0657_row4_col5" class="data row4 col5" >.</td>
#       <td id="T_c0657_row4_col6" class="data row4 col6" >False</td>
#       <td id="T_c0657_row4_col7" class="data row4 col7" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Check if the Japanese NLP model works
jdoc = jnlp("こんにちは！日本語の例文を自然言語処理で解釈します。")
j_tokens_info = []

for token in jdoc:
    j_tokens_info.append([token.text, token.lemma_, token.pos_,
                          token.tag_, token.dep_, token.shape_, token.is_alpha, token.is_stop])

j_table = pd.DataFrame(columns=headers, data=j_tokens_info)
j_table = left_align(j_table)
j_table
# Out:
# <style type="text/css">
# #T_c313d_ th {
#   text-align: left;
# }
# #T_c313d_row0_col0, #T_c313d_row0_col1, #T_c313d_row0_col2, #T_c313d_row0_col3, #T_c313d_row0_col4, #T_c313d_row0_col5, #T_c313d_row0_col6, #T_c313d_row0_col7, #T_c313d_row1_col0, #T_c313d_row1_col1, #T_c313d_row1_col2, #T_c313d_row1_col3, #T_c313d_row1_col4, #T_c313d_row1_col5, #T_c313d_row1_col6, #T_c313d_row1_col7, #T_c313d_row2_col0, #T_c313d_row2_col1, #T_c313d_row2_col2, #T_c313d_row2_col3, #T_c313d_row2_col4, #T_c313d_row2_col5, #T_c313d_row2_col6, #T_c313d_row2_col7, #T_c313d_row3_col0, #T_c313d_row3_col1, #T_c313d_row3_col2, #T_c313d_row3_col3, #T_c313d_row3_col4, #T_c313d_row3_col5, #T_c313d_row3_col6, #T_c313d_row3_col7, #T_c313d_row4_col0, #T_c313d_row4_col1, #T_c313d_row4_col2, #T_c313d_row4_col3, #T_c313d_row4_col4, #T_c313d_row4_col5, #T_c313d_row4_col6, #T_c313d_row4_col7, #T_c313d_row5_col0, #T_c313d_row5_col1, #T_c313d_row5_col2, #T_c313d_row5_col3, #T_c313d_row5_col4, #T_c313d_row5_col5, #T_c313d_row5_col6, #T_c313d_row5_col7, #T_c313d_row6_col0, #T_c313d_row6_col1, #T_c313d_row6_col2, #T_c313d_row6_col3, #T_c313d_row6_col4, #T_c313d_row6_col5, #T_c313d_row6_col6, #T_c313d_row6_col7, #T_c313d_row7_col0, #T_c313d_row7_col1, #T_c313d_row7_col2, #T_c313d_row7_col3, #T_c313d_row7_col4, #T_c313d_row7_col5, #T_c313d_row7_col6, #T_c313d_row7_col7, #T_c313d_row8_col0, #T_c313d_row8_col1, #T_c313d_row8_col2, #T_c313d_row8_col3, #T_c313d_row8_col4, #T_c313d_row8_col5, #T_c313d_row8_col6, #T_c313d_row8_col7, #T_c313d_row9_col0, #T_c313d_row9_col1, #T_c313d_row9_col2, #T_c313d_row9_col3, #T_c313d_row9_col4, #T_c313d_row9_col5, #T_c313d_row9_col6, #T_c313d_row9_col7, #T_c313d_row10_col0, #T_c313d_row10_col1, #T_c313d_row10_col2, #T_c313d_row10_col3, #T_c313d_row10_col4, #T_c313d_row10_col5, #T_c313d_row10_col6, #T_c313d_row10_col7, #T_c313d_row11_col0, #T_c313d_row11_col1, #T_c313d_row11_col2, #T_c313d_row11_col3, #T_c313d_row11_col4, #T_c313d_row11_col5, #T_c313d_row11_col6, #T_c313d_row11_col7, #T_c313d_row12_col0, #T_c313d_row12_col1, #T_c313d_row12_col2, #T_c313d_row12_col3, #T_c313d_row12_col4, #T_c313d_row12_col5, #T_c313d_row12_col6, #T_c313d_row12_col7, #T_c313d_row13_col0, #T_c313d_row13_col1, #T_c313d_row13_col2, #T_c313d_row13_col3, #T_c313d_row13_col4, #T_c313d_row13_col5, #T_c313d_row13_col6, #T_c313d_row13_col7, #T_c313d_row14_col0, #T_c313d_row14_col1, #T_c313d_row14_col2, #T_c313d_row14_col3, #T_c313d_row14_col4, #T_c313d_row14_col5, #T_c313d_row14_col6, #T_c313d_row14_col7 {
#   text-align: left;
# }
# </style>
# <table id="T_c313d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Text</th>
#       <th class="col_heading level0 col1" >Lemma</th>
#       <th class="col_heading level0 col2" >POS</th>
#       <th class="col_heading level0 col3" >Tag</th>
#       <th class="col_heading level0 col4" >Dep</th>
#       <th class="col_heading level0 col5" >Shape</th>
#       <th class="col_heading level0 col6" >Is Alpha</th>
#       <th class="col_heading level0 col7" >Is Stop</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c313d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c313d_row0_col0" class="data row0 col0" >こんにちは</td>
#       <td id="T_c313d_row0_col1" class="data row0 col1" >こんにちは</td>
#       <td id="T_c313d_row0_col2" class="data row0 col2" >INTJ</td>
#       <td id="T_c313d_row0_col3" class="data row0 col3" >感動詞-一般</td>
#       <td id="T_c313d_row0_col4" class="data row0 col4" >advcl</td>
#       <td id="T_c313d_row0_col5" class="data row0 col5" >xxxx</td>
#       <td id="T_c313d_row0_col6" class="data row0 col6" >True</td>
#       <td id="T_c313d_row0_col7" class="data row0 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c313d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c313d_row1_col0" class="data row1 col0" >！</td>
#       <td id="T_c313d_row1_col1" class="data row1 col1" >!</td>
#       <td id="T_c313d_row1_col2" class="data row1 col2" >PUNCT</td>
#       <td id="T_c313d_row1_col3" class="data row1 col3" >補助記号-句点</td>
#       <td id="T_c313d_row1_col4" class="data row1 col4" >aux</td>
#       <td id="T_c313d_row1_col5" class="data row1 col5" >！</td>
#       <td id="T_c313d_row1_col6" class="data row1 col6" >False</td>
#       <td id="T_c313d_row1_col7" class="data row1 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c313d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c313d_row2_col0" class="data row2 col0" >日本</td>
#       <td id="T_c313d_row2_col1" class="data row2 col1" >日本</td>
#       <td id="T_c313d_row2_col2" class="data row2 col2" >PROPN</td>
#       <td id="T_c313d_row2_col3" class="data row2 col3" >名詞-固有名詞-地名-国</td>
#       <td id="T_c313d_row2_col4" class="data row2 col4" >compound</td>
#       <td id="T_c313d_row2_col5" class="data row2 col5" >xx</td>
#       <td id="T_c313d_row2_col6" class="data row2 col6" >True</td>
#       <td id="T_c313d_row2_col7" class="data row2 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c313d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c313d_row3_col0" class="data row3 col0" >語</td>
#       <td id="T_c313d_row3_col1" class="data row3 col1" >語</td>
#       <td id="T_c313d_row3_col2" class="data row3 col2" >NOUN</td>
#       <td id="T_c313d_row3_col3" class="data row3 col3" >名詞-普通名詞-一般</td>
#       <td id="T_c313d_row3_col4" class="data row3 col4" >nmod</td>
#       <td id="T_c313d_row3_col5" class="data row3 col5" >x</td>
#       <td id="T_c313d_row3_col6" class="data row3 col6" >True</td>
#       <td id="T_c313d_row3_col7" class="data row3 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c313d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c313d_row4_col0" class="data row4 col0" >の</td>
#       <td id="T_c313d_row4_col1" class="data row4 col1" >の</td>
#       <td id="T_c313d_row4_col2" class="data row4 col2" >ADP</td>
#       <td id="T_c313d_row4_col3" class="data row4 col3" >助詞-格助詞</td>
#       <td id="T_c313d_row4_col4" class="data row4 col4" >case</td>
#       <td id="T_c313d_row4_col5" class="data row4 col5" >x</td>
#       <td id="T_c313d_row4_col6" class="data row4 col6" >True</td>
#       <td id="T_c313d_row4_col7" class="data row4 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c313d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c313d_row5_col0" class="data row5 col0" >例文</td>
#       <td id="T_c313d_row5_col1" class="data row5 col1" >例文</td>
#       <td id="T_c313d_row5_col2" class="data row5 col2" >NOUN</td>
#       <td id="T_c313d_row5_col3" class="data row5 col3" >名詞-普通名詞-一般</td>
#       <td id="T_c313d_row5_col4" class="data row5 col4" >obj</td>
#       <td id="T_c313d_row5_col5" class="data row5 col5" >xx</td>
#       <td id="T_c313d_row5_col6" class="data row5 col6" >True</td>
#       <td id="T_c313d_row5_col7" class="data row5 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c313d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c313d_row6_col0" class="data row6 col0" >を</td>
#       <td id="T_c313d_row6_col1" class="data row6 col1" >を</td>
#       <td id="T_c313d_row6_col2" class="data row6 col2" >ADP</td>
#       <td id="T_c313d_row6_col3" class="data row6 col3" >助詞-格助詞</td>
#       <td id="T_c313d_row6_col4" class="data row6 col4" >case</td>
#       <td id="T_c313d_row6_col5" class="data row6 col5" >x</td>
#       <td id="T_c313d_row6_col6" class="data row6 col6" >True</td>
#       <td id="T_c313d_row6_col7" class="data row6 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c313d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c313d_row7_col0" class="data row7 col0" >自然</td>
#       <td id="T_c313d_row7_col1" class="data row7 col1" >自然</td>
#       <td id="T_c313d_row7_col2" class="data row7 col2" >NOUN</td>
#       <td id="T_c313d_row7_col3" class="data row7 col3" >名詞-普通名詞-一般</td>
#       <td id="T_c313d_row7_col4" class="data row7 col4" >compound</td>
#       <td id="T_c313d_row7_col5" class="data row7 col5" >xx</td>
#       <td id="T_c313d_row7_co
