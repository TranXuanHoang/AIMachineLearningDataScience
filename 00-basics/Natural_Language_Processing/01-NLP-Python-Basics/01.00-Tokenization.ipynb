# %% [markdown]
# # Tokenization
#
# [Tokenization](https://spacy.io/usage/linguistic-features#tokenization) is a process in which a given input text is split into meaningful words, punctuation and so on. These outputs are called *tokens*.

# %%
import pandas as pd
import spacy

# %%
# Load NLP models (both English and Japanese)
enlp = spacy.load('en_core_web_trf')
jnlp = spacy.load('ja_core_news_lg')

# %%
# Create a string that includes opening and closing quotation marks
estring1 = '"We\'re moving to L.A.!"'
print(estring1)
# Out:
# "We're moving to L.A.!"

# %%
jstring1 = '「２０２０年の東京オリンピックが成功になるように！」'
print(jstring1)
# Out:
# 「２０２０年の東京オリンピックが成功になるように！」

# %%
edoc1 = enlp(estring1)
jdoc1 = jnlp(jstring1)

# %%
for token in edoc1:
    print(token.text)
# Out:
# "
# We
# 're
# moving
# to
# L.A.
# !
# "

# %%
for token in jdoc1:
    print(token.text)
# Out:
# 「
# ２０２０
# 年
# の
# 東京
# オリンピック
# が
# 成功
# に
# なる
# よう
# に
# ！
# 」

# %%
def tokensInfo(doc: spacy.tokens.doc.Doc):
    # Extract and save information of each token as a child array
    # of the parent tokens_info[] array
    tokens_info = []
    for token in doc:
        tokens_info.append([token.text, token.lemma_, token.pos_, token.tag_,
                            token.dep_, token.shape_, token.is_alpha, token.is_stop])

    # Table header
    headers = ["Text", "Lemma", "POS", "Tag", "Dep", "Shape", "Is Alpha", "Is Stop"]
    
    # Create and return a Pandas DataFrame containing information of all tokens
    table = pd.DataFrame(columns=headers, data=tokens_info)
    return table

# %%
edoc2 = enlp(u'New York, often called New York City to distinguish it from New York State, \
or NYC for short, is the most populous city in the United States. With a 2020 population of \
8,804,190 distributed over 300.46 square miles (778.2 km2), New York City is also the most \
densely populated major city in the United States.')
print(edoc2)
# Out:
# New York, often called New York City to distinguish it from New York State, or NYC for short, is the most populous city in the United States. With a 2020 population of 8,804,190 distributed over 300.46 square miles (778.2 km2), New York City is also the most densely populated major city in the United States.

# %%
tokensInfo(edoc2).head(20)
# Out:
#            Text        Lemma    POS  Tag       Dep  Shape  Is Alpha  Is Stop
# 0           New          New  PROPN  NNP  compound    Xxx      True    False
# 1          York         York  PROPN  NNP     nsubj   Xxxx      True    False
# 2             ,            ,  PUNCT    ,     punct      ,     False    False
# 3         often        often    ADV   RB    advmod   xxxx      True     True
# 4        called         call   VERB  VBN       acl   xxxx      True    False
# 5           New          New  PROPN  NNP  compound    Xxx      True    False
# 6          York         York  PROPN  NNP  compound   Xxxx      True    False
# 7          City         City  PROPN  NNP      oprd   Xxxx      True    False
# 8            to           to   PART   TO       aux     xx      True     True
# 9   distinguish  distinguish   VERB   VB     advcl   xxxx      True    False
# 10           it           it   PRON  PRP      dobj     xx      True     True
# 11         from         from    ADP   IN      prep   xxxx      True     True
# 12          New          New  PROPN  NNP  compound    Xxx      True    False
# 13         York         York  PROPN  NNP  compound   Xxxx      True    False
# 14        State        State  PROPN  NNP      pobj  Xxxxx      True    False
# 15            ,            ,  PUNCT    ,     punct      ,     False    False
# 16           or           or  CCONJ   CC        cc     xx      True     True
# 17          NYC          NYC  PROPN  NNP      conj    XXX      True    False
# 18          for          for    ADP   IN      prep    xxx      True     True
# 19        short        short    ADJ   JJ      amod   xxxx      True    False

# %%
jdoc2 = jnlp(u'松野官房長官は、30日午後の記者会見で、アフリカ南部のナミビアから入国した30代の男性が、\
新型コロナの新たな変異ウイルス「オミクロン株」に感染していたことが確認されたことを明らかにしました。\
日本国内で、オミクロン株の感染者が確認されたのは初めてです。\
この中で松野官房長官は「ナミビアからの入国者について、国立感染症研究所で陽性検体のゲノム解析を行ったところ、\
オミクロン株であると確認されたとの1報が、厚生労働省からあった」と述べ、アフリカ南部のナミビアから入国した\
30代の男性が、新型コロナの新たな変異ウイルス「オミクロン株」に感染していたことが確認されたことを明らかにしました。')
print(jdoc2)
# Out:
# 松野官房長官は、30日午後の記者会見で、アフリカ南部のナミビアから入国した30代の男性が、新型コロナの新たな変異ウイルス「オミクロン株」に感染していたことが確認されたことを明らかにしました。日本国内で、オミクロン株の感染者が確認されたのは初めてです。この中で松野官房長官は「ナミビアからの入国者について、国立感染症研究所で陽性検体のゲノム解析を行ったところ、オミクロン株であると確認されたとの1報が、厚生労働省からあった」と述べ、アフリカ南部のナミビアから入国した30代の男性が、新型コロナの新たな変異ウイルス「オミクロン株」に感染していたことが確認されたことを明らかにしました。

# %%
tokensInfo(jdoc2).head(50)
# Out:
#      Text  Lemma    POS            Tag       Dep Shape  Is Alpha  Is Stop
# 0      松野     松野  PROPN   名詞-固有名詞-人名-姓  compound    xx      True    False
# 1      官房     官房   NOUN     名詞-普通名詞-一般  compound    xx      True    False
# 2      長官     長官   NOUN     名詞-普通名詞-一般     nsubj    xx      True    False
# 3       は      は    ADP         助詞-係助詞      case     x      True     True
# 4       、      、  PUNCT        補助記号-読点     punct     、     False    False
# 5      30     30    NUM          名詞-数詞    nummod    dd     False    False
# 6       日      日   NOUN  名詞-普通名詞-助数詞可能  compound     x      True    False
# 7      午後     午後   NOUN   名詞-普通名詞-副詞可能      nmod    xx      True    False
# 8       の      の    ADP         助詞-格助詞      case     x      True     True
# 9      記者     記者   NOUN     名詞-普通名詞-一般  compound    xx      True    False
# 10     会見     会見   NOUN   名詞-普通名詞-サ変可能     advcl    xx      True    False
# 11      で      で    ADP         助詞-格助詞      case     x      True     True
# 12      、      、  PUNCT        補助記号-読点     punct     、     False    False
# 13   アフリカ   アフリカ  PROPN  名詞-固有名詞-地名-一般  compound  xxxx      True    False
# 14     南部     南部   NOUN     名詞-普通名詞-一般      nmod    xx      True    False
# 15      の      の    ADP         助詞-格助詞      case     x      True     True
# 16   ナミビア   ナミビア  PROPN   名詞-固有名詞-地名-国       obl  xxxx      True    False
# 17     から     から    ADP         助詞-格助詞      case    xx      True     True
# 18     入国     入国   VERB   名詞-普通名詞-サ変可能       acl    xx      True    False
# 19      し     する    AUX       動詞-非自立可能       aux     x      True     True
# 20      た      た    AUX            助動詞       aux     x      True     True
# 21     30     30    NUM          名詞-数詞    nummod    dd     False    False
# 22      代      代   NOUN  名詞-普通名詞-助数詞可能      nmod     x      True    False
# 23      の      の    ADP         助詞-格助詞      case     x      True     True
# 24     男性     男性   NOUN     名詞-普通名詞-一般     nsubj    xx      True    False
# 25      が      が    ADP         助詞-格助詞      case     x      True     True
# 26      、      、  PUNCT        補助記号-読点     punct     、     False    False
# 27     新型     新型   NOUN     名詞-普通名詞-一般  compound    xx      True    False
# 28    コロナ    コロナ   NOUN     名詞-普通名詞-一般      nmod   xxx      True    False
# 29      の      の    ADP         助詞-格助詞      case     x      True     True
# 30     新た     新た    ADJ         形状詞-一般       acl    xx      True    False
# 31      な      だ    AUX            助動詞       aux     x      True     True
# 32     変異     変異   NOUN   名詞-普通名詞-サ変可能  compound    xx      True    False
# 33   ウイルス   ウイルス   NOUN     名詞-普通名詞-一般  compound  xxxx      True    False
# 34      「      「  PUNCT       補助記号-括弧開     punct     「     False    False
# 35  オミクロン  オミクロン   NOUN     名詞-普通名詞-一般  compound  xxxx      True    False
# 36      株      株   NOUN  名詞-普通名詞-助数詞可能       obl     x      True    False
# 37      」      」  PUNCT       補助記号-括弧閉     punct     」     False    False
# 38      に      に    ADP         助詞-格助詞      case     x      True     True
# 39     感染     感染   VERB   名詞-普通名詞-サ変可能       acl    xx      True    False
# 40      し     する    AUX       動詞-非自立可能       aux     x      True     True
# 41      て      て  SCONJ        助詞-接続助詞      mark     x      True     True
# 42      い     いる    AUX       動詞-非自立可能       aux     x      True     True
# 43      た      た    AUX            助動詞       aux     x      True     True
# 44     こと     こと   NOUN     名詞-普通名詞-一般     nsubj    xx      True     True
# 45      が      が    ADP         助詞-格助詞      case     x      True     True
# 46     確認     確認   VERB   名詞-普通名詞-サ変可能       acl    xx      True    False
# 47      さ     する    AUX       動詞-非自立可能       aux     x      True     True
# 48      れ     れる    AUX            助動詞       aux     x      True     True
# 49      た      た    AUX            助動詞       aux     x      True     True

# %% [markdown]
# ### Prefixes, Suffixes, Infixes and Exceptions
#
# - **Prefix**:	Character(s) at the beginning &#9656; `$ ( “ ¿`
# - **Suffix**:	Character(s) at the end &#9656; `km ) , . ! ”`
# - **Infix**:	Character(s) in between &#9656; `- -- / ...`
# - **Exception**: Special-case rule to split a string into several tokens or prevent a token from being split when punctuation rules are applied &#9656; `St. U.S.`, or “don’t” does not contain whitespace, but should be split into two tokens, “do” and “n’t”, while “U.K.” should always remain one token.

# %% [markdown]
# ## Counting Tokens

# %%
len(edoc1)
# Out:
# 8

# %%
len(jdoc1)
# Out:
# 14

# %%
len(jdoc2)
# Out:
# 180

# %% [markdown]
# ## Counting Vocab Entries

# %%
len(edoc1.vocab)
# Out:
# 800

# %%
len(jdoc1.vocab)
# Out:
# 79

# %%
len(jdoc2.vocab)
# Out:
# 79

# %%
enlp.vocab.length
# Out:
# 800

# %%
jnlp.vocab.length
# Out:
# 79

# %% [markdown]
# ## Named Entities
#
# [Named entities](https://spacy.io/usage/linguistic-features#named-entities) are available as the `ents` properties of the `Doc` and represent *real-world* objects - i.e., a person, a country, a product or a book title.

# %%
def namedEntitiesInfo(doc: spacy.tokens.doc.Doc):
    entities_info = []
    
    for ent in doc.ents:
        entities_info.append([ent, ent.text, ent.label_, spacy.explain(ent.label_)])
    
    headers = ['Entity', '.text', '.label_', 'Explanation']
    entities_df = pd.DataFrame(data=entities_info, columns=headers)
    return entities_df

# %%
namedEntitiesInfo(edoc2)
# Out:
#                      Entity                .text   .label_  \
# 0               (New, York)             New York       GPE
# 1         (New, York, City)        New York City       GPE
# 2        (New, York, State)       New York State       GPE
# 3                     (NYC)                  NYC       GPE
# 4     (the, United, States)    the United States       GPE
# 5                    (2020)                 2020      DATE
# 6               (8,804,190)            8,804,190  CARDINAL
# 7   (300.46, square, miles)  300.46 square miles  QUANTITY
# 8              (778.2, km2)            778.2 km2  QUANTITY
# 9         (New, York, City)        New York City       GPE
# 10    (the, United, States)    the United States       GPE
#
#                                      Explanation
# 0                      Countries, cities, states
# 1                      Countries, cities, states
# 2                      Countries, cities, states
# 3                      Countries, cities, states
# 4                      Countries, cities, states
# 5          Absolute or relative dates or periods
# 6   Numerals that do not fall under another type
# 7         Measurements, as of weight or distance
# 8         Measurements, as of weight or distance
# 9                      Countries, cities, states
# 10                     Countries, cities, states

# %% [markdown]
# <font color=green>Note `spaCy` is able to recognize `New York City` is an entity of type `Countries, cities, states`, `300.46 square miles` is a `QUANTITY` entity.</font>

# %%
namedEntitiesInfo(jdoc2)
# Out:
#          Entity   .text      .label_  \
# 0          (松野)      松野       PERSON
# 1      (官房, 長官)    官房長官  TITLE_AFFIX
# 2   (30, 日, 午後)   30日午後         DATE
# 3        (アフリカ)    アフリカ          GPE
# 4        (ナミビア)    ナミビア          GPE
# 5       (30, 代)     30代     QUANTITY
# 6    (オミクロン, 株)  オミクロン株      PRODUCT
# 7          (日本)      日本          GPE
# 8    (オミクロン, 株)  オミクロン株      PRODUCT
# 9          (松野)      松野       PERSON
# 10     (官房, 長官)    官房長官  TITLE_AFFIX
# 11       (ナミビア)    ナミビア          GPE
# 12   (オミクロン, 株)  オミクロン株      PRODUCT
# 13       (1, 報)      1報     QUANTITY
# 14  (厚生, 労働, 省)   厚生労働省          ORG
# 15       (アフリカ)    アフリカ          GPE
# 16       (ナミビア)    ナミビア          GPE
# 17      (30, 代)     30代     QUANTITY
# 18   (オミクロン, 株)  オミクロン株      PRODUCT
#
#                                       Explanation
# 0                     People, including fictional
# 1                                            None
# 2           Absolute or relative dates or periods
# 3                       Countries, cities, states
# 4                       Countries, cities, states
# 5          Measurements, as of weight or distance
# 6   Objects, vehicles, foods, etc. (not services)
# 7                       Countries, cities, states
# 8   Objects, vehicles, foods, etc. (not services)
# 9                     People, including fictional
# 10                                           None
# 11                      Countries, cities, states
# 12  Objects, vehicles, foods, etc. (not services)
# 13         Measurements, as of weight or distance
# 14        Companies, agencies, institutions, etc.
# 15                      Countries, cities, states
# 16                      Countries, cities, states
# 17         Measurements, as of weight or distance
# 18  Objects, vehicles, foods, etc. (not services)

# %% [markdown]
# <font color=green>Note how named entity `30日午後` is formed from 3 tokens, or two tokens `(30, 代)` is combined into a single entity `30代`.</font>

# %% [markdown]
# ## Noun Chunks
#
# [Noun chunks](https://spacy.io/usage/linguistic-features#noun-chunks) are "base noun phrases" that can be seen as *a noun plus the words describing the noun* - i.e., "red carpet", "delicious cake". Similar to getting entities with `Doc.ents`, we can get a list of `noun chunks` of a `Doc` by refering `Doc.noun_chunks`.

# %%
def nounChunksInfo(doc: spacy.tokens.doc.Doc):
    noun_chunks_info = []
    
    for chunk in doc.noun_chunks:
        noun_chunks_info.append([
            chunk, chunk.text,
            chunk.label_,
            chunk.root.text,
            chunk.root.dep_,
            chunk.root.head.text,
            spacy.explain(chunk.root.dep_)
        ])
    
    headers = [
        'Noun Chunk',
        '.text',
        '.label_',
        '.root.text',
        '.root.dep_',
        '.root.head.text',
        'Explanation (.root.dep_)'
    ]
    noun_chunks_info = pd.DataFrame(data=noun_chunks_info, columns=headers)
    return noun_chunks_info

# %% [markdown]
# <font color=magenta>
#
# In the above `nounChunksInfo` function:
#
# - **Text** (`chunk.text`): The original noun chunk text.
# - **Root text** (`chunk.root.text`): The original text of the word connecting the noun chunk to the rest of the parse.
# - **Root dep** (`chunk.root.dep_`): Dependency relation connecting the root to its head.
# - **Root head text** (`chunk.root.head.text`): The text of the root token’s head.
# </font>

# %%
nounChunksInfo(edoc2)
# Out:
#                                       Noun Chunk  \
# 0                                    (New, York)
# 1                              (New, York, City)
# 2                                           (it)
# 3                             (New, York, State)
# 4                    (the, most, populous, city)
# 5                          (the, United, States)
# 6                          (a, 2020, population)
# 7                        (300.46, square, miles)
# 8                              (New, York, City)
# 9   (the, most, densely, populated, major, city)
# 10                         (the, United, States)
#
#                                     .text .label_  .root.text .root.dep_  \
# 0                                New York      NP        York      nsubj
# 1                           New York City      NP        City       oprd
# 2                                      it      NP          it       dobj
# 3                          New York State      NP       State       pobj
# 4                  the most populous city      NP        city       attr
# 5                       the United States      NP      States       pobj
# 6                       a 2020 population      NP  population       pobj
# 7                     300.46 square miles      NP       miles       pobj
# 8                           New York City      NP        City      nsubj
# 9   the most densely populated major city      NP        city       attr
# 10                      the United States      NP      States       pobj
#
#    .root.head.text Explanation (.root.dep_)
# 0               is          nominal subject
# 1           called         object predicate
# 2      distinguish            direct object
# 3             from    object of preposition
# 4               is                attribute
# 5               in    object of preposition
# 6             With    object of preposition
# 7             over    object of preposition
# 8               is          nominal subject
# 9               is                attribute
# 10              in    object of preposition

# %%
nounChunksInfo(jdoc2)
# Out:
#                                        Noun Chunk                .text  \
# 0                                    (松野, 官房, 長官)               松野官房長官
# 1                                     (30, 日, 午後)                30日午後
# 2                                      (アフリカ, 南部)               アフリカ南部
# 3                                          (ナミビア)                 ナミビア
# 4                                         (30, 代)                  30代
# 5                                            (男性)                   男性
# 6                                       (新型, コロナ)                新型コロナ
# 7                  (新た, な, 変異, ウイルス, 「, オミクロン, 株)     新たな変異ウイルス「オミクロン株
# 8                                            (こと)                   こと
# 9                                        (日本, 国内)                 日本国内
# 10                                     (オミクロン, 株)               オミクロン株
# 11                                        (感染, 者)                  感染者
# 12                                        (この, 中)                  この中
# 13                                   (松野, 官房, 長官)               松野官房長官
# 14                                      (「, ナミビア)                「ナミビア
# 15                                        (入国, 者)                  入国者
# 16                             (国立, 感染, 症, 研究, 所)             国立感染症研究所
# 17                                       (陽性, 検体)                 陽性検体
# 18                       (ゲノム, 解析, を, 行っ, た, ところ)         ゲノム解析を行ったところ
# 19  (オミクロン, 株, で, ある, と, 確認, さ, れ, た, と, の, 1, 報)  オミクロン株であると確認されたとの1報
# 20                                    (厚生, 労働, 省)                厚生労働省
# 21                                     (アフリカ, 南部)               アフリカ南部
# 22                                         (ナミビア)                 ナミビア
# 23                                        (30, 代)                  30代
# 24                                           (男性)                   男性
# 25                                      (新型, コロナ)                新型コロナ
# 26                 (新た, な, 変異, ウイルス, 「, オミクロン, 株)     新たな変異ウイルス「オミクロン株
# 27                                           (こと)                   こと
#
#    .label_ .root.text .root.dep_ .root.head.text Explanation (.root.dep_)
# 0       NP         長官      nsubj               し          nominal subject
# 1       NP         午後       nmod              会見      modifier of nominal
# 2       NP         南部       nmod            ナミビア      modifier of nominal
# 3       NP       ナミビア        obl              入国          oblique nominal
# 4       NP          代       nmod              男性      modifier of nominal
# 5       NP         男性      nsubj              感染          nominal subject
# 6       NP        コロナ       nmod               株      modifier of nominal
# 7       NP          株        obl              感染          oblique nominal
# 8       NP         こと      nsubj              確認          nominal subject
# 9       NP         国内        obl             初めて          oblique nominal
# 10      NP          株       nmod               者      modifier of nominal
# 11      NP          者      nsubj              確認          nominal subject
# 12      NP          中        obl              行っ          oblique nominal
# 13      NP         長官      nsubj              行っ          nominal subject
# 14      NP       ナミビア       nmod               者      modifier of nominal
# 15      NP          者        obl              行っ          oblique nominal
# 16      NP          所        obl              行っ          oblique nominal
# 17      NP         検体       nmod              解析      modifier of nominal
# 18      NP        ところ        obl              述べ          oblique nominal
# 19      NP          報      nsubj              あっ          nominal subject
# 20      NP          省        obl              あっ          oblique nominal
# 21      NP         南部       nmod            ナミビア      modifier of nominal
# 22      NP       ナミビア        obl              入国          oblique nominal
# 23      NP          代       nmod              男性      modifier of nominal
# 24      NP         男性      nsubj              感染          nominal subject
# 25      NP        コロナ       nmod               株      modifier of nominal
# 26      NP          株        obl              感染          oblique nominal
# 27      NP         こと      nsubj              確認          nominal subject

# %% [markdown]
# ## Visualizers
#
# `spaCy`'s built-in [visualizers](https://spacy.io/usage/visualizers) [displaCy](https://explosion.ai/demos/displacy) and [displaCy ENT](https://explosion.ai/demos/displacy-ent) provide functions for visualizing dependencies and entities in web browsers or in a notebook. There are two main visualization styles:
#
# - dependency parse: `displacy.render(style='dep', ...)`
# - named entities: `displacy.render(style='ent', ...)`

# %%
from spacy import displacy

# %%
displacy.render(edoc1, style='dep', jupyter=True, options={'distance': 110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e62a7e0746a644f1abb9849a3d2f92cd-0" class="displacy" width="710" height="302.0" direction="ltr" style="max-width: none; height: 302.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">&quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">We</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">'re</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">moving</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">L.A.!&quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e62a7e0746a644f1abb9849a3d2f92cd-0-0" stroke-width="2px" d="M70,167.0 C70,2.0 380.0,2.0 380.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e62a7e0746a644f1abb9849a3d2f92cd-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,169.0 L62,157.0 78,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e62a7e0746a644f1abb9849a3d2f92cd-0-1" stroke-width="2px" d="M180,167.0 C180,57.0 375.0,57.0 375.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e62a7e0746a644f1abb9849a3d2f92cd-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M180,169.0 L172,157.0 188,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e62a7e0746a644f1abb9849a3d2f92cd-0-2" stroke-width="2px" d="M290,167.0 C290,112.0 370.0,112.0 370.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e62a7e0746a644f1abb9849a3d2f92cd-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290,169.0 L282,157.0 298,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e62a7e0746a644f1abb9849a3d2f92cd-0-3" stroke-width="2px" d="M400,167.0 C400,112.0 480.0,112.0 480.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e62a7e0746a644f1abb9849a3d2f92cd-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M480.0,169.0 L488.0,157.0 472.0,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e62a7e0746a644f1abb9849a3d2f92cd-0-4" stroke-width="2px" d="M510,167.0 C510,112.0 590.0,112.0 590.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e62a7e0746a644f1abb9849a3d2f92cd-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M590.0,169.0 L598.0,157.0 582.0,157.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
displacy.render(edoc1, style='ent', jupyter=True, options={'distance': 110})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">&quot;We're moving to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     L.A.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# !&quot;</div></span>

# %%
displacy.render(jdoc1, style='dep', jupyter=True, options={'distance': 110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ja" id="f939ea6fcf3c43afb3be9cabb5de97c7-0" class="displacy" width="1370" height="357.0" direction="ltr" style="max-width: none; height: 357.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">「</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">２０２０</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">年</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">の</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">東京</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">オリンピック</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">が</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">成功</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">に</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">なる</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">よう</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">に！」</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">PUNCT</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f939ea6fcf3c43afb3be9cabb5de97c7-0-0" stroke-width="2px" d="M70,222.0 C70,112.0 260.0,112.0 260.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f939ea6fcf3c43afb3be9cabb5de97c7-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,224.0 L62,212.0 78,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f939ea6fcf3c43afb3be9cabb5de97c7-0-1" stroke-width="2px" d="M180,222.0 C180,167.0 255.0,167.0 255.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f939ea6fcf3c43afb3be9cabb5de97c7-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M180,224.0 L172,212.0 188,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f939ea6fcf3c43afb3be9cabb5de97c7-0-2" stroke-width="2px" d="M290,222.0 C290,57.0 595.0,57.0 595.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f939ea6fcf3c43afb3be9cabb5de97c7-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290,224.0 L282,212.0 298,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f939ea6fcf3c43afb3be9cabb5de97c7-0-3" stroke-width="2px" d="M290,222.0 C290,167.0 365.0,167.0 365.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f939ea6fcf3c43afb3be9cabb5de97c7-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M365.0,224.0 L373.0,212.0 357.0,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f939ea6fcf3c43afb3be9cabb5de97c7-0-4" stroke-width="2px" d="M510,222.0 C510,167.0 585.0,167.0 585.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f939ea6fcf3c43afb3be9cabb5de97c7-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M510,224.0 L502,212.0 518,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f939ea6fcf3c43afb3be9cabb5de97c7-0-5" stroke-width="2px" d="M620,222.0 C620,2.0 1040.0,2.0 1040.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f939ea6fcf3c43afb3be9cabb5de97c7-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M620,224.0 L612,212.0 628,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f939ea6fcf3c43afb3be9cabb5de97c7-0-6" stroke-width="2px" d="M620,222.0 C620,167.0 695.0,167.0 695.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f939ea6fcf3c43afb3be9cabb5de97c7-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M695.0,224.0 L703.0,212.0 687.0,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f939ea6fcf3c43afb3be9cabb5de97c7-0-7" stroke-width="2px" d="M840,222.0 C840,112.0 1030.0,112.0 1030.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f939ea6fcf3c43afb3be9cabb5de97c7-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M840,224.0 L832,212.0 848,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f939ea6fcf3c43afb3be9c

# %%
displacy.render(jdoc1, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">「
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ２０２０年
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# の
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     東京オリンピック
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
# が成功になるように！」</div></span>

# %%
displacy.render(edoc2, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , often called
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York City
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to distinguish it from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York State
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , or
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NYC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  for short, is the most populous city in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . With a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  population of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8,804,190
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  distributed over
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     300.46 square miles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     778.2 km2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# ),
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York City
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is also the most densely populated major city in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</div></span>

# %%
displacy.render(jdoc2, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     松野
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     官房長官
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TITLE_AFFIX</span>
# </mark>
# は、
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30日午後
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# の記者会見で、
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     アフリカ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 南部の
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ナミビア
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# から入国した
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30代
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# の男性が、新型コロナの新たな変異ウイルス「
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     オミクロン株
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# 」に感染していたことが確認されたことを明らかにしました。
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     日本
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 国内で、
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     オミクロン株
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# の感染者が確認されたのは初めてです。この中で
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     松野
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     官房長官
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TITLE_AFFIX</span>
# </mark>
# は「
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ナミビア
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# からの入国者について、国立感染症研究所で陽性検体のゲノム解析を行ったところ、
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     オミクロン株
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# であると確認されたとの
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1報
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# が、
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     厚生労働省
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# からあった」と述べ、
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     アフリカ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 南部の
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ナミビア
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# から入国した
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30代
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# の男性が、新型コロナの新たな変異ウイルス「
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     オミクロン株
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# 」に感染していたことが確認されたことを明らかにしました。</div></span>

# %% [markdown]
# ### Visualizing Long Text
#
# Long texts can become difficult to read when displayed in one row, so it’s often better to visualize them sentence-by-sentence instead.

# %%
# Split a long text into sentences, then visualize those sentences
e_sentences_2 = list(edoc2.sents)
displacy.render(e_sentences_2, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , often called
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York City
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to distinguish it from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York State
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , or
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NYC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  for short, is the most populous city in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">With a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  population of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8,804,190
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  distributed over
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     300.46 square miles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     778.2 km2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# ),
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York City
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is also the most densely populated major city in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</div></span>

# %% [markdown]
# ### Visualization Options

# %%
options = {"compact": True, "bg": "#09a3d5",
           "color": "white", "font": "Source Sans Pro"}
displacy.render(edoc1, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="459aa48d9d90439c9349d18d8efffd04-0" class="displacy" width="950" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">&quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">We</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">'re</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">moving</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">L.A.!&quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-459aa48d9d90439c9349d18d8efffd04-0-0" stroke-width="2px" d="M62,227.0 62,152.0 500.0,152.0 500.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-459aa48d9d90439c9349d18d8efffd04-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,229.0 L58,221.0 66,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-459aa48d9d90439c9349d18d8efffd04-0-1" stroke-width="2px" d="M212,227.0 212,177.0 497.0,177.0 497.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-459aa48d9d90439c9349d18d8efffd04-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,229.0 L208,221.0 216,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-459aa48d9d90439c9349d18d8efffd04-0-2" stroke-width="2px" d="M362,227.0 362,202.0 494.0,202.0 494.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-459aa48d9d90439c9349d18d8efffd04-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,229.0 L358,221.0 366,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-459aa48d9d90439c9349d18d8efffd04-0-3" stroke-width="2px" d="M512,227.0 512,202.0 644.0,202.0 644.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-459aa48d9d90439c9349d18d8efffd04-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M644.0,229.0 L648.0,221.0 640.0,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-459aa48d9d90439c9349d18d8efffd04-0-4" stroke-width="2px" d="M662,227.0 662,202.0 794.0,202.0 794.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-459aa48d9d90439c9349d18d8efffd04-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M794.0,229.0 L798.0,221.0 790.0,221.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
colors = {
    "DATE": "linear-gradient(90deg, #aa9cfc, #fc9ce7)",
    "EVENT": "linear-gradient(90deg, green, yellow)",
}
options = {"colors": colors}
jdoc1.user_data['title'] = '東京オリンピックテキストの視覚化'
displacy.render(jdoc1, style='ent', options=options)
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">東京オリンピックテキストの視覚化</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">「
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ２０２０年
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# の
# <mark class="entity" style="background: linear-gradient(90deg, green, yellow); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     東京オリンピック
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
# が成功になるように！」</div></span>

# %%
colors = {
    "NOUN": "linear-gradient(90deg, #aa9cfc, #fc9ce7)",
    "PROPN": "linear-gradient(90deg, green, yellow)",
}
options = {
    "compact": True,
    "bg": "linear-gradient(90deg, #aa9cfc, #fc9ce7)", # background color
    "font": "Arial",
    "color": colors
}
displacy.render(jdoc1, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ja" id="21646eb2b90b4af5a010b73391927cf3-0" class="displacy" width="1850" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: {'NOUN': 'linear-gradient(90deg, #aa9cfc, #fc9ce7)', 'PROPN': 'linear-gradient(90deg, green, yellow)'}; background: linear-gradient(90deg, #aa9cfc, #fc9ce7); font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">「</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">２０２０</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">年</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">の</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">東京</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">オリンピック</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">が</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">成功</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">に</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">なる</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">よう</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">に！」</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">PUNCT</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-21646eb2b90b4af5a010b73391927cf3-0-0" stroke-width="2px" d="M62,302.0 62,252.0 344.0,252.0 344.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-21646eb2b90b4af5a010b73391927cf3-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,304.0 L58,296.0 66,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-21646eb2b90b4af5a010b73391927cf3-0-1" stroke-width="2px" d="M212,302.0 212,277.0 341.0,277.0 341.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-21646eb2b90b4af5a010b73391927cf3-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,304.0 L208,296.0 216,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-21646eb2b90b4af5a010b73391927cf3-0-2" stroke-width="2px" d="M362,302.0 362,227.0 797.0,227.0 797.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-21646eb2b90b4af5a010b73391927cf3-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,304.0 L358,296.0 366,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-21646eb2b90b4af5a010b73391927cf3-0-3" stroke-width="2px" d="M362,302.0 362,277.0 491.0,277.0 491.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-21646eb2b90b4af5a010b73391927cf3-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M491.0,304.0 L495.0,296.0 487.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-21646eb2b90b4af5a010b73391927cf3-0-4" stroke-width="2px" d="M662,302.0 662,277.0 791.0,277.0 791.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-21646eb2b90b4af5a010b73391927cf3-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M662,304.0 L658,296.0 666,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-21646eb2b90b4af5a010b73391927cf3-0-5" stroke-width="2px" d="M812,302.0 812,202.0 1400.0,202.0 1400.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-21646eb2b90b4af5a010b73391927cf3-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M812,304.0 L808,296.0 816,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-21646eb2b90b4af5a010b73391927cf3-0-6" stroke-width="2px" d="M812,302.0 812,277.0 941.0,277.0 941.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-21646eb2b90b4af5a010b73391927cf3-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M941.0,304.0 L945.0,296.0 937.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-21646eb2b90b4af5a010b73391927cf3-0-7" stroke-width="2px" d="M1112,302.0 1112,252.0 1394.0,252.0 1394.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-21646eb2b90b4af5a010b73391927cf3-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1112,304.0 L1108,2

# %% [markdown]
# ### Visualization as a Webpage

# %%
displacy.serve(edoc2, style='ent')
# Out:
# C:\Users\hoang.tran\Desktop\Home\Workplace\AIMachineLearningDataScience\00-basics\env\lib\site-packages\spacy\displacy\__init__.py:97: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , often called
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York City
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to distinguish it from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York State
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , or
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NYC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  for short, is the most populous city in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . With a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  population of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8,804,190
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  distributed over
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     300.46 square miles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     778.2 km2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# ),
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York City
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is also the most densely populated major city in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</div>
# </figure>
# </body>
# </html></span>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %% [markdown]
# <font color='magenta'>
#     After running the above cell, open a web browser and load <a href='http://localhost:5000/'>http://localhost:5000/</a>
#
# To stop serving the page, go back to this notebook, select the above `cell` and
# - either press `Esc`, then `I` twice
# - or click on 'Interrupt the kernel' square button in the top toolbar
# </font>
